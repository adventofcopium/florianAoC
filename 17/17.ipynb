# %% [markdown]
# # Advent of Code 2023 - Day 10: **Pipe Maze**

# %% [markdown]
# ### Preparation

# %%
import numpy as np
import heapq as hq
from queue import PriorityQueue
from dataclasses import dataclass

# %%
with open('test.txt', 'r') as f:
    data = np.array([[int(c) for c in list(line)] for line in f.read().splitlines()]).T
width, height = data.shape

# %%
class Node:
    pos : (int, int)
    g : np.float32 = np.inf
    f : np.float32 = np.inf
    parent : 'Node' = None
    neighbourrs : list['Node'] = None
    dir_last : (int, int) = (0,0)
    dir_count : int = 0
    
    def __init__(self, pos : (int, int)) -> None:
        self.pos = pos
        
    def __eq__(self, other):
        return self.pos == other.pos
    
    def __lt__(self, other):
        return self.g < other.g
    
    def __add__(self, other):
        return self.pos[0] + other.pos[0], self.pos[1] + other.pos[1]
    
    def __sub__(self, other):
        return self.pos[0] - other.pos[0], self.pos[1] - other.pos[1]
    
    def inbounds(self):
        return (0 <= self.pos[0] < width) and (0 <= self.pos[1] < height)

    def h(self, other):
        return abs(self.pos[0] - other.pos[0]) + abs(self.pos[1] - other.pos[1])
    
    def __str__(self) -> str:
        return f'N{self.pos}, g={self.g}, par={self.parent.pos if self.parent else None}, dir={self.dir_last}, dir_count={self.dir_count}'
    
    # def get_board_repr(self):
        
    
def heuristic(a, b):
    return abs(a[0] - b[0]) + abs(a[1] - b[1])

# %%
# def print_grid(grid):
#     for row in grid:
#         nodes =

# %%
grid = [[Node((x, y)) for y in range(height)] for x in range(width)]
for x in range(width):
    for y in range(height):
        grid[x][y].neighbourrs = [grid[nx][ny] for nx, ny in [(x-1, y), (x+1, y), (x, y-1), (x, y+1)] if (0 <= nx < width) and (0 <= ny < height)]

# %%
openlist : list[Node] = []
closedlist : list[Node] = []
start = grid[0][0]
start.g = 0
goal = grid[width-1][height-1]

num_grid = np.zeros((width, height))

def expand_node(current, openlist, closedlist):
    for successor in current.neighbourrs:
        dir = current - successor
        if current.dir_last == dir:
            if current.dir_count < 2:
                successor.dir_count = current.dir_count + 1
            else:
                continue
        if current.dir_last != dir:
            successor.dir_count = 0
            successor.dir_last = dir
        
        if successor in closedlist:
            continue
        tent_g = current.g + data[successor.pos]
        if successor in (node[1] for node in openlist):
            if tent_g >= successor.g:
                continue
        successor.parent = current
        successor.g = tent_g
        f = tent_g + successor.h(goal)
        
        index = None
        for i, node in enumerate(openlist):
            if node[1] == successor:
                index = i
                break
        if index:
            openlist[index] = (f, successor)
            hq.heapify(openlist)
        else:
            hq.heappush(openlist, (f, successor))
        
        num_grid[successor.pos] = f
            
hq.heappush(openlist, (0, start))

while openlist:
    current = hq.heappop(openlist)[1]
    print(current)
    if current == goal:
        break
    closedlist.append(current)
    expand_node(current, openlist, closedlist)
    

print('path:')
path = []
current = goal
while current.parent:
    print(current)
    path.append(current)
    current = current.parent
    
print(num_grid)
# Out:
# N(0, 0), g=0, par=None, dir=(1, 0), dir_count=0
# N(0, 1), g=3, par=(0, 0), dir=(0, -1), dir_count=0
# N(1, 0), g=4, par=(0, 0), dir=(-1, 0), dir_count=0
# N(1, 1), g=5, par=(0, 1), dir=(0, -1), dir_count=0
# N(2, 0), g=5, par=(1, 0), dir=(1, 0), dir_count=1
# N(2, 1), g=6, par=(1, 1), dir=(0, -1), dir_count=0
# N(0, 2), g=6, par=(0, 1), dir=(0, 1), dir_count=1
# N(1, 2), g=7, par=(1, 1), dir=(-1, 0), dir_count=0
# N(3, 0), g=8, par=(2, 0), dir=(-1, 0), dir_count=0
# N(0, 3), g=9, par=(0, 2), dir=(0, -1), dir_count=0
# N(2, 2), g=11, par=(2, 1), dir=(1, 0), dir_count=1
# N(3, 1), g=11, par=(2, 1), dir=(0, -1), dir_count=0
# N(1, 3), g=11, par=(1, 2), dir=(-1, 0), dir_count=0
# N(4, 0), g=12, par=(3, 0), dir=(1, 0), dir_count=1
# N(0, 4), g=13, par=(0, 3), dir=(1, 0), dir_count=1
# N(0, 5), g=14, par=(0, 4), dir=(0, -1), dir_count=0
# N(4, 1), g=15, par=(3, 1), dir=(0, -1), dir_count=0
# N(5, 0), g=15, par=(4, 0), dir=(-1, 0), dir_count=0
# N(2, 3), g=15, par=(2, 2), dir=(0, -1), dir_count=1
# N(3, 2), g=16, par=(2, 2), dir=(-1, 0), dir_count=1
# N(1, 4), g=16, par=(1, 3), dir=(-1, 0), dir_count=0
# N(4, 2), g=17, par=(4, 1), dir=(0, 1), dir_count=2
# N(6, 0), g=17, par=(5, 0), dir=(1, 0), dir_count=1
# N(1, 5), g=18, par=(0, 5), dir=(0, -1), dir_count=0
# N(0, 6), g=18, par=(0, 5), dir=(1, 0), dir_count=1
# N(2, 4), g=19, par=(2, 3), dir=(1, 0), dir_count=1
# N(6, 1), g=20, par=(6, 0), dir=(0, -1), dir_count=0
# N(7, 0), g=20, par=(6, 0), dir=(-1, 0), dir_count=0
# N(8, 0), g=21, par=(7, 0), dir=(0, 1), dir_count=1
# N(9, 0), g=22, par=(8, 0), dir=(-1, 0), dir_count=0
# N(5, 1), g=20, par=(4, 1), dir=(1, 0), dir_count=0
# N(5, 2), g=21, par=(4, 2), dir=(0, -1), dir_count=0
# N(0, 7), g=21, par=(0, 6), dir=(0, -1), dir_count=0
# N(2, 5), g=21, par=(1, 5), dir=(0, -1), dir_count=0
# N(3, 3), g=21, par=(2, 3), dir=(0, -1), dir_count=0
# N(4, 3), g=22, par=(4, 2), dir=(-1, 0), dir_count=0
# N(1, 6), g=22, par=(1, 5), dir=(-1, 0), dir_count=0
# N(8, 1), g=24, par=(8, 0), dir=(0, -1), dir_count=0
# N(10, 0), g=25, par=(9, 0), dir=(0, 1), dir_count=1
# N(11, 0), g=27, par=(10, 0), dir=(-1, 0), dir_count=0
# N(7, 1), g=25, par=(6, 1), dir=(1, 0), dir_count=0
# N(6, 2), g=25, par=(6, 1), dir=(-1, 0), dir_count=0
# N(0, 8), g=25, par=(0, 7), dir=(1, 0), dir_count=1
# N(9, 1), g=27, par=(9, 0), dir=(-1, 0), dir_count=0
# N(11, 1), g=29, par=(11, 0), dir=(0, -1), dir_count=0
# N(3, 4), g=25, par=(2, 4), dir=(-1, 0), dir_count=1
# N(2, 6), g=26, par=(2, 5), dir=(1, 0), dir_count=1
# N(12, 0), g=30, par=(11, 0), dir=(0, 1), dir_count=1
# N(1, 7), g=27, par=(0, 7), dir=(0, -1), dir_count=0
# N(8, 2), g=29, par=(8, 1), dir=(0, 1), dir_count=1
# N(12, 1), g=32, par=(11, 1), dir=(0, -1), dir_count=0
# N(4, 4), g=28, par=(4, 3), dir=(0, -1), dir_count=2
# N(0, 9), g=29, par=(0, 8), dir=(0, -1), dir_count=0
# N(2, 7), g=29, par=(2, 6), dir=(-1, 0), dir_count=0
# N(0, 10), g=30, par=(0, 9), dir=(1, 0), dir_count=1
# N(10, 1), g=31, par=(10, 0), dir=(1, 0), dir_count=0
# N(9, 2), g=31, par=(9, 1), dir=(-1, 0), dir_count=0
# N(3, 5), g=29, par=(2, 5), dir=(0, -1), dir_count=0
# N(5, 3), g=29, par=(5, 2), dir=(0, 1), dir_count=1
# N(6, 3), g=30, par=(6, 2), dir=(-1, 0), dir_count=0
# N(0, 11), g=32, par=(0, 10), dir=(0, -1), dir_count=0
# N(1, 10), g=32, par=(0, 10), dir=(-1, 0), dir_count=0
# N(10, 2), g=33, par=(10, 1), dir=(0, -1), dir_count=1
# N(11, 2), g=34, par=(11, 1), dir=(-1, 0), dir_count=0
# N(1, 8), g=31, par=(0, 8), dir=(-1, 0), dir_count=1
# N(7, 2), g=31, par=(7, 1), dir=(1, 0), dir_count=0
# N(8, 3), g=33, par=(8, 2), dir=(0, -1), dir_count=0
# N(2, 10), g=34, par=(1, 10), dir=(0, -1), dir_count=1
# N(12, 2), g=36, par=(12, 1), dir=(0, 1), dir_count=1
# N(12, 3), g=38, par=(12, 2), dir=(0, -1), dir_count=0
# N(5, 4), g=33, par=(4, 4), dir=(0, -1), dir_count=0
# N(3, 6), g=33, par=(2, 6), dir=(-1, 0), dir_count=1
# N(1, 9), g=34, par=(0, 9), dir=(0, -1), dir_count=0
# N(2, 8), g=34, par=(2, 7), dir=(0, -1), dir_count=2
# N(0, 12), g=36, par=(0, 11), dir=(1, 0), dir_count=1
# N(9, 3), g=36, par=(9, 2), dir=(-1, 0), dir_count=0
# N(10, 3), g=37, par=(10, 2), dir=(0, 1), dir_count=1
# N(4, 5), g=34, par=(3, 5), dir=(-1, 0), dir_count=0
# N(1, 11), g=37, par=(0, 11), dir=(0, -1), dir_count=0
# N(2, 11), g=38, par=(2, 10), dir=(-1, 0), dir_count=0
# N(3, 10), g=38, par=(2, 10), dir=(-1, 0), dir_count=0
# N(11, 3), g=39, par=(11, 2), dir=(-1, 0), dir_count=0
# N(3, 7), g=36, par=(2, 7), dir=(0, -1), dir_count=0
# N(1, 12), g=39, par=(0, 12), dir=(-1, 0), dir_count=1
# N(2, 12), g=40, par=(2, 11), dir=(0, -1), dir_count=2
# N(6, 4), g=37, par=(6, 3), dir=(-1, 0), dir_count=0
# N(3, 8), g=38, par=(2, 8), dir=(-1, 0), dir_count=1
# N(8, 4), g=39, par=(8, 3), dir=(0, 1), dir_count=1
# N(11, 4), g=42, par=(11, 3), dir=(0, -1), dir_count=0
# N(3, 12), g=42, par=(2, 12), dir=(-1, 0), dir_count=0
# N(7, 3), g=38, par=(6, 3), dir=(1, 0), dir_count=0
# N(10, 4), g=42, par=(10, 3), dir=(1, 0), dir_count=0
# N(12, 4), g=44, par=(12, 3), dir=(-1, 0), dir_count=0
# N(2, 9), g=40, par=(2, 10), dir=(-1, 0), dir_count=0
# N(3, 9), g=42, par=(3, 10), dir=(0, -1), dir_count=1
# N(9, 4), g=43, par=(9, 3), dir=(-1, 0), dir_count=1
# N(3, 11), g=44, par=(2, 11), dir=(0, 1), dir_count=0
# N(4, 10), g=44, par=(3, 10), dir=(1, 0), dir_count=1
# N(4, 6), g=41, par=(3, 6), dir=(0, -1), dir_count=0
# N(10, 5), g=46, par=(10, 4), dir=(0, -1), dir_count=0
# N(11, 5), g=47, par=(11, 4), dir=(-1, 0), dir_count=0
# N(12, 5), g=48, par=(12, 4), dir=(0, -1), dir_count=1
# N(5, 5), g=42, par=(5, 4), dir=(0, 1), dir_count=1
# N(4, 12), g=48, par=(3, 12), dir=(1, 0), dir_count=1
# N(4, 7), g=44, par=(3, 7), dir=(-1, 0), dir_count=1
# N(6, 5), g=45, par=(6, 4), dir=(-1, 0), dir_count=0
# N(7, 4), g=45, par=(6, 4), dir=(0, -1), dir_count=0
# N(4, 11), g=49, par=(3, 11), dir=(0, 1), dir_count=0
# N(4, 8), g=47, par=(3, 8), dir=(0, -1), dir_count=0
# N(4, 9), g=48, par=(3, 9), dir=(0, 1), dir_count=1
# N(8, 5), g=48, par=(8, 4), dir=(0, -1), dir_count=0
# N(11, 6), g=53, par=(11, 5), dir=(0, -1), dir_count=0
# N(12, 6), g=54, par=(12, 5), dir=(-1, 0), dir_count=0
# N(5, 6), g=48, par=(4, 6), dir=(0, -1), dir_count=0
# N(9, 5), g=51, par=(9, 4), dir=(-1, 0), dir_count=0
# N(5, 10), g=52, par=(4, 10), dir=(-1, 0), dir_count=0
# N(5, 11), g=53, par=(4, 11), dir=(0, -1), dir_count=0
# N(10, 6), g=53, par=(10, 5), dir=(1, 0), dir_count=0
# N(5, 12), g=55, par=(4, 12), dir=(-1, 0), dir_count=1
# N(12, 7), g=57, par=(12, 6), dir=(0, -1), dir_count=0
# N(6, 6), g=51, par=(6, 5), dir=(-1, 0), dir_count=0
# N(5, 7), g=51, par=(4, 7), dir=(1, 0), dir_count=1
# N(7, 5), g=52, par=(6, 5), dir=(1, 0), dir_count=0
# N(5, 8), g=53, par=(4, 8), dir=(0, -1), dir_count=0
# N(11, 7), g=58, par=(11, 6), dir=(1, 0), dir_count=0
# N(5, 9), g=55, par=(4, 9), dir=(0, 1), dir_count=1
# N(6, 12), g=59, par=(5, 12), dir=(1, 0), dir_count=2
# N(8, 6), g=56, par=(8, 5), dir=(0, 1), dir_count=1
# N(6, 10), g=58, par=(5, 10), dir=(1, 0), dir_count=1
# N(10, 7), g=59, par=(10, 6), dir=(0, -1), dir_count=1
# N(9, 6), g=58, par=(9, 5), dir=(-1, 0), dir_count=0
# N(6, 11), g=61, par=(5, 11), dir=(0, -1), dir_count=0
# N(12, 8), g=64, par=(12, 7), dir=(-1, 0), dir_count=1
# N(6, 7), g=58, par=(6, 6), dir=(-1, 0), dir_count=0
# N(6, 8), g=60, par=(5, 8), dir=(0, -1), dir_count=0
# N(7, 12), g=65, par=(6, 12), dir=(-1, 0), dir_count=0
# N(12, 9), g=67, par=(12, 8), dir=(0, -1), dir_count=0
# N(7, 6), g=60, par=(6, 6), dir=(1, 0), dir_count=0
# N(11, 8), g=66, par=(11, 7), dir=(1, 0), dir_count=0
# N(8, 7), g=63, par=(8, 6), dir=(0, -1), dir_count=0
# N(12, 10), g=70, par=(12, 9), dir=(0, 1), dir_count=1
# N(6, 9), g=64, par=(5, 9), dir=(0, 1), dir_count=1
# N(7, 10), g=66, par=(6, 10), dir=(-1, 0), dir_count=0
# N(10, 8), g=67, par=(10, 7), dir=(0, 1), dir_count=1
# N(8, 12), g=70, par=(7, 12), dir=(1, 0), dir_count=1
# N(9, 7), g=67, par=(9, 6), dir=(-1, 0), dir_count=0
# N(7, 11), g=69, par=(6, 11), dir=(0, -1), dir_count=0
# N(11, 9), g=71, par=(11, 8), dir=(0, -1), dir_count=0
# N(10, 9), g=71, par=(10, 8), dir=(1, 0), dir_count=0
# N(12, 11), g=75, par=(12, 10), dir=(0, -1), dir_count=0
# N(7, 7), g=67, par=(6, 7), dir=(1, 0), dir_count=0
# N(7, 8), g=69, par=(6, 8), dir=(0, -1), dir_count=0
# N(8, 10), g=72, par=(7, 10), dir=(0, 0), dir_count=1
# N(9, 12), g=75, par=(8, 12), dir=(-1, 0), dir_count=0
# N(12, 12), g=78, par=(12, 11), dir=(0, 0), dir_count=1
# path:
# N(12, 12), g=78, par=(12, 11), dir=(0, 0), dir_count=1
# N(12, 11), g=75, par=(12, 10), dir=(0, -1), dir_count=0
# N(12, 10), g=70, par=(12, 9), dir=(0, 1), dir_count=0
# N(12, 9), g=67, par=(12, 8), dir=(-1, 0), dir_count=0
# N(12, 8), g=64, par=(12, 7), dir=(-1, 0), dir_count=0
# N(12, 7), g=57, par=(12, 6), dir=(0, 1), dir_count=0
# N(12, 6), g=54, par=(12, 5), dir=(0, 1), dir_count=0
# N(12, 5), g=48, par=(12, 4), dir=(0, 1), dir_count=0
# N(12, 4), g=44, par=(12, 3), dir=(0, 1), dir_count=0
# N(12, 3), g=38, par=(12, 2), dir=(0, 1), dir_count=0
# N(12, 2), g=36, par=(12, 1), dir=(0, 1), dir_count=0
# N(12, 1), g=32, par=(11, 1), dir=(0, -1), dir_count=2
# N(11, 1), g=29, par=(11, 0), dir=(0, 1), dir_count=0
# N(11, 0), g=27, par=(10, 0), dir=(1, 0), dir_count=0
# N(10, 0), g=25, par=(9, 0), dir=(0, 1), dir_count=0
# N(9, 0), g=22, par=(8, 0), dir=(0, 1), dir_count=0
# N(8, 0), g=21, par=(7, 0), dir=(0, 1), dir_count=0
# N(7, 0), g=20, par=(6, 0), dir=(0, 1), dir_count=0
# N(6, 0), g=17, par=(5, 0), dir=(1, 0), dir_count=0
# N(5, 0), g=15, par=(4, 0), dir=(0, 1), dir_count=0
# N(4, 0), g=12, par=(3, 0), dir=(1, 0), dir_count=0
# N(3, 0), g=8, par=(2, 0), dir=(0, 1), dir_count=2
# N(2, 0), g=5, par=(1, 0), dir=(1, 0), dir_count=0
# N(1, 0), g=4, par=(0, 0), dir=(0, 1), dir_count=2
# [[ 0. 26. 28. 30. 33. 33. 36. 38. 41. 44. 44. 45. 48.]
#  [27. 27. 28. 31. 35. 36. 39. 43. 46. 48. 45. 49. 50.]
#  [27. 27. 31. 34. 37. 38. 42. 44. 48. 53. 46. 49. 50.]
#  [29. 31. 35. 39. 42. 45. 48. 50. 51. 54. 49. 54. 51.]
#  [32. 34. 35. 39. 44. 49. 55. 57. 59. 59. 54. 58. 56.]
#  [34. 38. 38. 45. 48. 56. 61. 63. 64. 65. 61. 61. 62.]
#  [35. 37. 41. 45. 51. 58. 63. 69. 70. 73. 66. 68. 65.]
#  [37. 41. 46. 52. 58. 64. 71. 77. 78. 81. 73. 75. 70.]
#  [37. 39. 43. 46. 51. 59. 66. 72. 79. 87. 78. 82. 74.]
#  [37. 41. 44. 48. 54. 61. 67. 75. 80. 83. 82. 86. 78.]
#  [39. 44. 45. 48. 52. 55. 61. 66. 73. 76. 80.  0. 82.]
#  [40. 41. 45. 49. 51. 55. 60. 64. 71. 75. 79. 80.  0.]
#  [42. 43. 46. 47. 52. 55. 60. 62. 68. 70. 72. 76. 78.]]
